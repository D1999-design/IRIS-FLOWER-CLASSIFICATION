# %% [markdown]
# <a href="https://colab.research.google.com/github/D1999-design/IRIS-FLOWER-CLASSIFICATION/blob/main/CAR_PRICE_PREDICTION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import the standard libraries
import pandas as pd,numpy as np,seaborn as sns,matplotlib .pyplot as plt
#import the sklearn libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
import math

# %%
data=pd.read_csv('/content/car data.csv')
data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Selling_type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# 2       Dealer       Manual      0
# 3       Dealer       Manual      0
# 4       Dealer       Manual      0

# %%
#shape of the data
data.shape
# Out:
# (301, 9)

# %%
#check the information of the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Driven_kms     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Selling_type   301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
#check the information of the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Driven_kms     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Selling_type   301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
data.describe().style.background_gradient(cmap='winter')
# Out:
# <style type="text/css">
# #T_7971b_row0_col0 {
#   background-color: #0025ec;
#   color: #f1f1f1;
# }
# #T_7971b_row0_col1, #T_7971b_row0_col2, #T_7971b_row0_col4, #T_7971b_row1_col0, #T_7971b_row4_col0, #T_7971b_row5_col0, #T_7971b_row6_col0, #T_7971b_row7_col0, #T_7971b_row7_col3 {
#   background-color: #00ff80;
#   color: #000000;
# }
# #T_7971b_row0_col3, #T_7971b_row1_col4, #T_7971b_row2_col0, #T_7971b_row2_col4, #T_7971b_row3_col1, #T_7971b_row3_col2, #T_7971b_row3_col3, #T_7971b_row3_col4, #T_7971b_row4_col1, #T_7971b_row4_col2, #T_7971b_row4_col4, #T_7971b_row5_col4, #T_7971b_row6_col4 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_7971b_row1_col1 {
#   background-color: #0003fe;
#   color: #f1f1f1;
# }
# #T_7971b_row1_col2 {
#   background-color: #0006fc;
#   color: #f1f1f1;
# }
# #T_7971b_row1_col3 {
#   background-color: #0012f6;
#   color: #f1f1f1;
# }
# #T_7971b_row2_col1 {
#   background-color: #0004fd;
#   color: #f1f1f1;
# }
# #T_7971b_row2_col2, #T_7971b_row4_col3 {
#   background-color: #0007fc;
#   color: #f1f1f1;
# }
# #T_7971b_row2_col3 {
#   background-color: #0013f6;
#   color: #f1f1f1;
# }
# #T_7971b_row3_col0 {
#   background-color: #00fe80;
#   color: #000000;
# }
# #T_7971b_row5_col1, #T_7971b_row7_col4 {
#   background-color: #0002fe;
#   color: #f1f1f1;
# }
# #T_7971b_row5_col2, #T_7971b_row6_col1 {
#   background-color: #0005fc;
#   color: #f1f1f1;
# }
# #T_7971b_row5_col3 {
#   background-color: #0010f7;
#   color: #f1f1f1;
# }
# #T_7971b_row6_col2 {
#   background-color: #0008fb;
#   color: #f1f1f1;
# }
# #T_7971b_row6_col3 {
#   background-color: #0018f3;
#   color: #f1f1f1;
# }
# #T_7971b_row7_col1 {
#   background-color: #001df0;
#   color: #f1f1f1;
# }
# #T_7971b_row7_col2 {
#   background-color: #004ed8;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7971b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7971b_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_7971b_level0_col1" class="col_heading level0 col1" >Selling_Price</th>
#       <th id="T_7971b_level0_col2" class="col_heading level0 col2" >Present_Price</th>
#       <th id="T_7971b_level0_col3" class="col_heading level0 col3" >Driven_kms</th>
#       <th id="T_7971b_level0_col4" class="col_heading level0 col4" >Owner</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7971b_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_7971b_row0_col0" class="data row0 col0" >301.000000</td>
#       <td id="T_7971b_row0_col1" class="data row0 col1" >301.000000</td>
#       <td id="T_7971b_row0_col2" class="data row0 col2" >301.000000</td>
#       <td id="T_7971b_row0_col3" class="data row0 col3" >301.000000</td>
#       <td id="T_7971b_row0_col4" class="data row0 col4" >301.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7971b_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_7971b_row1_col0" class="data row1 col0" >2013.627907</td>
#       <td id="T_7971b_row1_col1" class="data row1 col1" >4.661296</td>
#       <td id="T_7971b_row1_col2" class="data row1 col2" >7.628472</td>
#       <td id="T_7971b_row1_col3" class="data row1 col3" >36947.205980</td>
#       <td id="T_7971b_row1_col4" class="data row1 col4" >0.043189</td>
#     </tr>
#     <tr>
#       <th id="T_7971b_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_7971b_row2_col0" class="data row2 col0" >2.891554</td>
#       <td id="T_7971b_row2_col1" class="data row2 col1" >5.082812</td>
#       <td id="T_7971b_row2_col2" class="data row2 col2" >8.642584</td>
#       <td id="T_7971b_row2_col3" class="data row2 col3" >38886.883882</td>
#       <td id="T_7971b_row2_col4" class="data row2 col4" >0.247915</td>
#     </tr>
#     <tr>
#       <th id="T_7971b_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_7971b_row3_col0" class="data row3 col0" >2003.000000</td>
#       <td id="T_7971b_row3_col1" class="data row3 col1" >0.100000</td>
#       <td id="T_7971b_row3_col2" class="data row3 col2" >0.320000</td>
#       <td id="T_7971b_row3_col3" class="data row3 col3" >500.000000</td>
#       <td id="T_7971b_row3_col4" class="data row3 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7971b_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_7971b_row4_col0" class="data row4 col0" >2012.000000</td>
#       <td id="T_7971b_row4_col1" class="data row4 col1" >0.900000</td>
#       <td id="T_7971b_row4_col2" class="data row4 col2" >1.200000</td>
#       <td id="T_7971b_row4_col3" class="data row4 col3" >15000.000000</td>
#       <td id="T_7971b_row4_col4" class="data row4 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7971b_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_7971b_row5_col0" class="data row5 col0" >2014.000000</td>
#       <td id="T_7971b_row5_col1" class="data row5 col1" >3.600000</td>
#       <td id="T_7971b_row5_col2" class="data row5 col2" >6.400000</td>
#       <td id="T_7971b_row5_col3" class="data row5 col3" >32000.000000</td>
#       <td id="T_7971b_row5_col4" class="data row5 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7971b_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_7971b_row6_col0" class="data row6 col0" >2016.000000</td>
#       <td id="T_7971b_row6_col1" class="data row6 col1" >6.000000</td>
#       <td id="T_7971b_row6_col2" class="data row6 col2" >9.900000</td>
#       <td id="T_7971b_row6_col3" class="data row6 col3" >48767.000000</td>
#       <td id="T_7971b_row6_col4" class="data row6 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7971b_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_7971b_row7_col0" class="data row7 col0" >2018.000000</td>
#       <td id="T_7971b_row7_col1" class="data row7 col1" >35.000000</td>
#       <td id="T_7971b_row7_col2" class="data row7 col2" >92.600000</td>
#       <td id="T_7971b_row7_col3" class="data row7 col3" >500000.000000</td>
#       <td id="T_7971b_row7_col4" class="data row7 col4" >3.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
corr=data.corr().style.background_gradient(cmap='gray')
corr
# Out:
# <ipython-input-8-220bf36517a7>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=data.corr().style.background_gradient(cmap='gray')
# <style type="text/css">
# #T_4cfd0_row0_col0, #T_4cfd0_row1_col1, #T_4cfd0_row2_col2, #T_4cfd0_row3_col3, #T_4cfd0_row4_col4 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_4cfd0_row0_col1 {
#   background-color: #4c4c4c;
#   color: #f1f1f1;
# }
# #T_4cfd0_row0_col2, #T_4cfd0_row0_col3, #T_4cfd0_row0_col4, #T_4cfd0_row3_col0, #T_4cfd0_row4_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_4cfd0_row1_col0 {
#   background-color: #7f7f7f;
#   color: #f1f1f1;
# }
# #T_4cfd0_row1_col2 {
#   background-color: #e2e2e2;
#   color: #000000;
# }
# #T_4cfd0_row1_col3 {
#   background-color: #5c5c5c;
#   color: #f1f1f1;
# }
# #T_4cfd0_row1_col4 {
#   background-color: #141414;
#   color: #f1f1f1;
# }
# #T_4cfd0_row2_col0 {
#   background-color: #505050;
#   color: #f1f1f1;
# }
# #T_4cfd0_row2_col1 {
#   background-color: #e3e3e3;
#   color: #000000;
# }
# #T_4cfd0_row2_col3 {
#   background-color: #7a7a7a;
#   color: #f1f1f1;
# }
# #T_4cfd0_row2_col4 {
#   background-color: #292929;
#   color: #f1f1f1;
# }
# #T_4cfd0_row3_col1 {
#   background-color: #1b1b1b;
#   color: #f1f1f1;
# }
# #T_4cfd0_row3_col2 {
#   background-color: #3d3d3d;
#   color: #f1f1f1;
# }
# #T_4cfd0_row3_col4 {
#   background-color: #3a3a3a;
#   color: #f1f1f1;
# }
# #T_4cfd0_row4_col0 {
#   background-color: #393939;
#   color: #f1f1f1;
# }
# #T_4cfd0_row4_col2 {
#   background-color: #0d0d0d;
#   color: #f1f1f1;
# }
# #T_4cfd0_row4_col3 {
#   background-color: #676767;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4cfd0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4cfd0_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_4cfd0_level0_col1" class="col_heading level0 col1" >Selling_Price</th>
#       <th id="T_4cfd0_level0_col2" class="col_heading level0 col2" >Present_Price</th>
#       <th id="T_4cfd0_level0_col3" class="col_heading level0 col3" >Driven_kms</th>
#       <th id="T_4cfd0_level0_col4" class="col_heading level0 col4" >Owner</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4cfd0_level0_row0" class="row_heading level0 row0" >Year</th>
#       <td id="T_4cfd0_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_4cfd0_row0_col1" class="data row0 col1" >0.236141</td>
#       <td id="T_4cfd0_row0_col2" class="data row0 col2" >-0.047192</td>
#       <td id="T_4cfd0_row0_col3" class="data row0 col3" >-0.524342</td>
#       <td id="T_4cfd0_row0_col4" class="data row0 col4" >-0.182104</td>
#     </tr>
#     <tr>
#       <th id="T_4cfd0_level0_row1" class="row_heading level0 row1" >Selling_Price</th>
#       <td id="T_4cfd0_row1_col0" class="data row1 col0" >0.236141</td>
#       <td id="T_4cfd0_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_4cfd0_row1_col2" class="data row1 col2" >0.878914</td>
#       <td id="T_4cfd0_row1_col3" class="data row1 col3" >0.029187</td>
#       <td id="T_4cfd0_row1_col4" class="data row1 col4" >-0.088344</td>
#     </tr>
#     <tr>
#       <th id="T_4cfd0_level0_row2" class="row_heading level0 row2" >Present_Price</th>
#       <td id="T_4cfd0_row2_col0" class="data row2 col0" >-0.047192</td>
#       <td id="T_4cfd0_row2_col1" class="data row2 col1" >0.878914</td>
#       <td id="T_4cfd0_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_4cfd0_row2_col3" class="data row2 col3" >0.203618</td>
#       <td id="T_4cfd0_row2_col4" class="data row2 col4" >0.008058</td>
#     </tr>
#     <tr>
#       <th id="T_4cfd0_level0_row3" class="row_heading level0 row3" >Driven_kms</th>
#       <td id="T_4cfd0_row3_col0" class="data row3 col0" >-0.524342</td>
#       <td id="T_4cfd0_row3_col1" class="data row3 col1" >0.029187</td>
#       <td id="T_4cfd0_row3_col2" class="data row3 col2" >0.203618</td>
#       <td id="T_4cfd0_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_4cfd0_row3_col4" class="data row3 col4" >0.089216</td>
#     </tr>
#     <tr>
#       <th id="T_4cfd0_level0_row4" class="row_heading level0 row4" >Owner</th>
#       <td id="T_4cfd0_row4_col0" class="data row4 col0" >-0.182104</td>
#       <td id="T_4cfd0_row4_col1" class="data row4 col1" >-0.088344</td>
#       <td id="T_4cfd0_row4_col2" class="data row4 col2" >0.008058</td>
#       <td id="T_4cfd0_row4_col3" class="data row4 col3" >0.089216</td>
#       <td id="T_4cfd0_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Let's visualize the correlation matrix in the seaborn
sns.set(rc={'figure.figsize':(15,10)})
sns.heatmap(data.corr(),annot=True,cmap='rainbow')
# Out:
# <ipython-input-11-51a646b13176>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot=True,cmap='rainbow')
# <Axes: >

# %%
#data columns
data.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Driven_kms',
#        'Fuel_Type', 'Selling_type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
#Lets visualize the car names in the dataset
car_names=data['Car_Name'].value_counts()
#To visualize the top 20 car's sold
label=['city','corolla altis','verna','fortuner','brio','ciaz','innova','i20','grand i10','jazz','amaze','Royal Enfield Classic 350','ertiga','eon','sx4','alto k10','i10','swift','Bajaj Pulsar 150','Royal Enfield Thunder 350']
plt.figure(figsize=(16,9))
plt.pie(car_names[:20],labels=label, autopct='%1.2f%%')
plt.title("To visualize the top 20 cars sold",fontsize=32,fontweight='bold')
plt.show()

# %%
#Lets check the car model with selling price
car_selling_price=data[['Car_Name','Selling_Price']].groupby(['Car_Name','Selling_Price']).sum().reset_index().sort_values(by='Selling_Price',ascending=False)
import plotly.express as px
fig=px.histogram(car_selling_price,x='Car_Name',y='Selling_Price',title="To visualize the car model with selling price")
fig.update_layout(bargap=0.2,bargroupgap=0.1,plot_bgcolor='black')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="afe8ff95-488b-4583-9da7-4349e7b5a230" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("afe8ff95-488b-4583-9da7-4349e7b5a230")) {                    Plotly.newPlot(                        "afe8ff95-488b-4583-9da7-4349e7b5a230",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Car_Name=%{x}\u003cbr\u003esum of Selling_Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["land cruiser","fortuner","fortuner","innova","fortuner","innova","fortuner","innova","fortuner","innova","corolla altis","fortuner","fortuner","corolla altis","fortuner","corolla altis","creta","innova","elantra","city","elantra","innova","creta","city","city","city","city","fortuner","city","verna","fortuner","vitara brezza","city","verna","city","ciaz","city","city","city","city","city","city","verna","i20","ciaz","ertiga","city","ciaz","ciaz","corolla altis","jazz","ciaz","ertiga","city","corolla altis","corolla altis","ciaz","ciaz","city","jazz","jazz","s cross","verna","jazz","city","i20","verna","ertiga","ertiga","i20","jazz","swift","verna","corolla altis","corolla altis","baleno","ertiga","amaze","xcent","jazz","dzire","corolla altis","brio","grand i10","brio","verna","brio","grand i10","corolla altis","brio","i20","city","verna","grand i10","verna","city","verna","swift","etios cross","ignis","grand i10","verna","brio","sx4","corolla altis","etios g","etios gd","xcent","etios liva","dzire","swift","i20","amaze","etios cross","corolla altis","verna","sx4","xcent","grand i10","corolla altis","swift","city","etios g","corolla altis","i10","amaze","brio","etios liva","etios g","amaze","grand i10","corolla altis","amaze","i20","amaze","corolla altis","innova","brio","eon","innova","etios liva","city","ritz","i20","city","wagon r","eon","ritz","i10","eon","i20","city","alto k10","brio","swift","i10","sx4","eon","wagon r","i20","alto k10","wagon r","alto 800","innova","eon","i10","sx4","etios liva","ritz","alto k10","i10","alto k10","camry","ritz","jazz","sx4","dzire","city","eon","alto k10","sx4","Royal Enfield Thunder 500","UM Renegade Mojave","KTM RC200","corolla","Bajaj Dominar 400","Hyosung GT250R","Royal Enfield Classic 350","KTM RC390","omni","Royal Enfield Thunder 350","Royal Enfield Thunder 350","Royal Enfield Classic 350","KTM RC200","Mahindra Mojo XT300","Royal Enfield Thunder 350","Royal Enfield Classic 350","KTM 390 Duke ","Royal Enfield Classic 350","Royal Enfield Classic 350","Royal Enfield Thunder 500","Bajaj Pulsar RS200","wagon r","Royal Enfield Thunder 500","Royal Enfield Bullet 350","Royal Enfield Thunder 350","Royal Enfield Classic 350","Royal Enfield Classic 500","Royal Enfield Classic 500","Bajaj Avenger 220","Honda CB Hornet 160R","Yamaha FZ S V 2.0","Yamaha FZ 16","Bajaj Avenger 150","Honda CB Hornet 160R","Bajaj Avenger 220","Bajaj Avenger 220","TVS Apache RTR 160","Hero Extreme","Honda CBR 150","Bajaj Pulsar 150","Honda CB Hornet 160R","TVS Apache RTR 160","Bajaj Avenger 150 street","Bajaj Pulsar  NS 200","Bajaj Avenger 220 dtsi","Honda CBR 150","Yamaha FZ  v 2.0","Yamaha FZ S V 2.0","Hero Extreme","Bajaj Pulsar 220 F","Bajaj Pulsar 220 F","TVS Apache RTR 180","Hero Passion X pro","Yamaha Fazer ","Bajaj Pulsar NS 200","Honda Dream Yuga ","TVS Sport ","Yamaha FZ S V 2.0","Honda Activa 4G","Bajaj Avenger Street 220","Bajaj Avenger 220 dtsi","Activa 3g","Hero Passion Pro","TVS Apache RTR 180","Bajaj Pulsar NS 200","Honda Activa 4G","Hero Splender iSmart","Honda CB Trigger","TVS Apache RTR 160","Bajaj Pulsar 135 LS","Activa 4g","Yamaha FZ S ","Hero ...

# %%
#Lets import the labelencoder convert the categorial data to numerical
from sklearn.preprocessing import LabelEncoder,StandardScaler
label=LabelEncoder()
data['Car_Name']=label.fit_transform(data['Car_Name'])
data['Fuel_Type']=label.fit_transform(data['Fuel_Type'])
data['Selling_type']=label.fit_transform(data['Selling_type'])
data['Transmission']=label.fit_transform(data['Transmission'])

# %%
#Let's divided the data into input into target
X=data.drop(['Selling_Price'],axis=1)
Y=data['Selling_Price']

# %%
#normalize the data
scaler=StandardScaler()
#Let's normalize the train dataset
X=scaler.fit_transform(X)

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.25,random_state=42)

# %%
#Install the Linear regression model
linear=LinearRegression()
#let's fit the train data
linear.fit(X_train,Y_train)
#Prediction of the test data
linear_pred=linear.predict(X_test)

# %%
#Check the test score and train score to the LinearRegression algorithm
print(f'The Test_accuracy: {linear.score(X_test,Y_test)*100:.2f}')
#Train score for the data
print(f'The Train_accuracy: {linear.score(X_train,Y_train)*100:.2f}')
# Out:
# The Test_accuracy: 87.50
# The Train_accuracy: 87.75

# %% [markdown]
# # BY *REGRESSION*

# %%
#Install the decisiontreeregressor from sklearn
from sklearn.tree import DecisionTreeRegressor
#Install the model
tree=DecisionTreeRegressor(random_state=0)
#and fit the train data to the model
tree.fit(X_train,Y_train)
#Prediction of the test dataset
tree_pred=tree.predict(X_test)

# %%
#Check the test score and train score to the DecisionTreeRegressor algorithm
print(f'The Test_accuracy: {tree.score(X_test,Y_test)*100:.2f}')
#Train score for the data
print(f'The Train_accuracy: {tree.score(X_train,Y_train)*100:.2f}')
# Out:
# The Test_accuracy: 96.04
# The Train_accuracy: 100.00
